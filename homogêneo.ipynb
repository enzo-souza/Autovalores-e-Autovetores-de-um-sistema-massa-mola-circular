# %% [markdown]
# Avaliação 5

# %% [markdown]
# ![alt text](image.png)

# %% [markdown]
# ![alt text](image-1.png)

# %% [markdown]
# # Introdução
#
# O problema massa mola é um objeto de estudo do comportamento de um sistema que possui molas ligadas à molas. Com ele, é possível quantificar as frequências possíveis e todas as possibilidades de movimento para cada frequência em cada massa.
#
# Nesta questão, devemos estudar um sistema em que a última mola está ligada à primeira, ou seja, um sistema circular:
#
# ![alt text](image-2.png)

# %% [markdown]
# # Metodologia
#
# Utilizamos as bibliotecas Numpy para realizar os calculos de algebra liner e a biblioteca matplotlib para plotar os gráficos.
#
# As matrizes são criadas via código digitado.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#define os valores de  massa e da constante elástica:

massa = 1
k = 1
n = int(input())


#constroi tres matrizes homogêneas que serão usadas para os calculos da matriz a ser diagonalizada.

# Cria uma lista de números de 0 a n-1
a = []
for z in range(0,n):
    a.append(z)
#print(a)


matriz_massa =[]
matriz_k = []
matriz = []
for z in range (0,n):
    matriz_massa.append([])
    matriz_k.append([])
    matriz.append([])
    for y in range(0,n):
        matriz_massa[z].append(massa)
        matriz_k[z].append(k)
        matriz[z].append(0)

#printa as matrizes

'''print(matriz_massa)
print(matriz_k)
print(matriz)'''
# Out:
# 'print(matriz_massa)\nprint(matriz_k)\nprint(matriz)'

# %% [markdown]
# As equações dinâmicas do sistema são encontradas seguindo a funçãos dadas pelo professor. Porém, para o nosso caso em que a última massa está ligada à primeira, foi necessário utilizar a artimanha do operador "%" que encontra o valor equivalente em um dado conjunto. Exemplo: Se meu conjunto A é dado por [0,4], a posição A[5] == 0
#
# ![alt text](image-3.png)
#
#
# Neste primeiro momento, os cálculos são realizados para um sistema homogênio, ou seja, todas as massas e constantes elásticas são iguais:

# %%
#calcula os autovalores para um n definido na celula anterior em um 
# sistema homogeneo em que o a ultima massa está ligada a primeira.

a = []
for z in range(0,n):
    a.append(z)
#print(a)


for i in range(0,len(a)):
    for j in range (0,len(a)):
        
        #Elenca os valores da diagonal pr
        if i==(j%len(a)):
            matriz[i][j] = ((matriz_k[i][(j-1)%len(a)] + matriz_k[i][(j+1)%len(a)]) / matriz_massa[i][j])
        
        #Elenca os valores da diagonal secundária superior
        if i==((j-1)%len(a)):
            matriz[i][j] = -1*(matriz_k[i][j]) / (matriz_massa[i][j])

        #Elenca os valores da diagonal secundária inferior
        if i==((j+1)%len(a)):
            matriz[i][j] = -1*(matriz_k[i][j]) / (matriz_massa[i][j])

# Imprime a matriz resultante
'''print()
for p in matriz:
    print(p)'''
# Out:
# 'print()\nfor p in matriz:\n    print(p)'

# %% [markdown]
# Com as matrizes prontas, basta utilizas a função eig para diagonalizá-las e encontrar os autovalores (frequências possíveis) e autovetores (modo do conjunto):

# %%
import matplotlib.pyplot as plt

# Calcula os autovalores da matriz usando a biblioteca NumPy eig:
autovalores, autovetores  = np.linalg.eig(matriz)

#Na biblioteca eig, os autovetores são retornados na coluna, então precisamos transpor a matriz de autovetores para obter os autovetores como linhas.
autovalores.argsort()
autovetores.T
#print("autovetores:", autovetores[:,-1])


# Plota a densidade de estados (histograma dos autovalores)
plt.figure(figsize=(6,4))
plt.hist(autovalores, bins=25, density=True, alpha=0.7, color='blue')
plt.xlabel('Autovalores')
plt.ylabel('Densidade de estados')
plt.title('Densidade de estados dos autovalores')
plt.grid(True)
plt.show()


# Plota o primeiro autovetor em função de uma reta real x
x = np.arange(n)
plt.figure(figsize=(20,8))
plt.plot(x, autovetores[:,-1], marker='o', linestyle='-', color='blue')
plt.xlabel('x (reta real)')
plt.ylabel('Componentes do Primeiro Autovetor')
plt.title('Primeiro Autovetor vs x')
plt.grid(True)
plt.show()

# %% [markdown]
# O Histograma representa as possibilidades de frequências para o sistema e o gráfico apresenta os modos de vibração de casa massa.

# %%
#caso queira ver os autovetores:
print("autovetores:", autovetores[:,-1])
# Out:
# autovetores: [-0.00046599  0.09996421 -0.00581392 -0.09959897  0.01207088  0.09884066
#  -0.0182802  -0.09769227  0.02441737  0.09615833 -0.03045818 -0.0942449
#   0.03637879  0.09195953 -0.04215583 -0.08931124  0.0477665   0.08631047
#  -0.05318865 -0.08296908  0.0584009   0.07930025 -0.06338266 -0.07531845
#   0.06811428  0.07103941 -0.07257708 -0.06648001  0.07675346  0.06165824
#  -0.08062692 -0.05659314  0.08418219  0.05130468 -0.08740523 -0.04581375
#   0.09028332  0.04014202 -0.0928051  -0.03431186  0.09496062  0.02834629
#  -0.09674138 -0.02226885  0.09814034  0.01610353 -0.09915199 -0.00987465
#   0.09977233  0.0036068  -0.09999891  0.00267529  0.09983085 -0.00894681
#  -0.0992688   0.01518303  0.09831498 -0.02135932 -0.09697315  0.02745132
#   0.09524862 -0.03343499 -0.09314818  0.0392867   0.09068013 -0.04498336
#  -0.08785421  0.05050249  0.08468156 -0.05582232 -0.08117472  0.06092184
#   0.07734752 -0.06578093 -0.07321506  0.07038041  0.06879366 -0.07470213
#  -0.06410076  0.07872904  0.05915488 -0.08244524 -0.05397554  0.08583606
#   0.04858319 -0.08888813 -0.0429991   0.0915894   0.03724532 -0.09392921
#  -0.03134454  0.09589832  0.02532007 -0.09748896 -0.01919566  0.09869487
#   0.0129955  -0.09951126 -0.00674405  0.09993493  0.00046599 -0.09996421
#   0.00581392  0.09959897 -0.01207088 -0.09884066  0.0182802   0.09769227
#  -0.02441737 -0.09615833  0.03045818  0.0942449  -0.03637879 -0.09195953
#   0.04215583  0.08931124 -0.0477665  -0.08631047  0.05318865  0.08296908
#  -0.0584009  -0.07930025  0.06338266  0.07531845 -0.06811428 -0.07103941
#   0.07257708  0.06648001 -0.07675346 -0.06165824  0.08062692  0.05659314
#  -0.08418219 -0.05130468  0.08740523  0.04581375 -0.09028332 -0.04014202
#   0.0928051   0.03431186 -0.09496062 -0.02834629  0.09674138  0.02226885
#  -0.09814034 -0.01610353  0.09915199  0.00987465 -0.09977233 -0.0036068
#   0.09999891 -0.00267529 -0.09983085  0.00894681  0.0992688  -0.01518303
#  -0.09831498  0.02135932  0.09697315 -0.02745132 -0.09524862  0.03343499
#   0.09314818 -0.0392867  -0.09068013  0.04498336  0.08785421 -0.05050249
#  -0.08468156  0.05582232  0.08117472 -0.06092184 -0.07734752  0.06578093
#   0.07321506 -0.07038041 -0.06879366  0.07470213  0.06410076 -0.07872904
#  -0.05915488  0.08244524  0.05397554 -0.08583606 -0.04858319  0.08888813
#   0.0429991  -0.0915894  -0.03724532  0.09392921  0.03134454 -0.09589832
#  -0.02532007  0.09748896  0.01919566 -0.09869487 -0.0129955   0.09951126
#   0.00674405 -0.09993493]

# %% [markdown]
# # Defeito
#
# Entrando em um caso mais complexo, tiramos a homogeneidade do sistema a modificamos a massa de uma das partículas.
#
# (Favor, seguir para o arquivo de nome "Defeito")
